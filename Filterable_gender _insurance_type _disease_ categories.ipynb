# %%
import pandas  
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MultipleLocator

# %%
TC = pandas.read_csv("ICUSTAYS.csv")
##df = pandas.DataFrame.from_dict(fm_data, orient='index')
ICUSTAYS = pandas.DataFrame(TC)

# %%
TC = pandas.read_csv("PATIENTS.csv")
##df = pandas.DataFrame.from_dict(fm_data, orient='index')
PATIENTS = pandas.DataFrame(TC)

# %%
TC1 = pandas.read_csv("DIAGNOSES_ICD.csv")
##df = pandas.DataFrame.from_dict(fm_data, orient='index')
df3 = pandas.DataFrame(TC1)

# %%
TC = pandas.read_csv("D_ICD_DIAGNOSES.csv")
##df = pandas.DataFrame.from_dict(fm_data, orient='index')
df = pandas.DataFrame(TC)

# %%
df1 = df.drop(columns=['ROW_ID'])
df1
# Out:
#       ICD9_CODE               SHORT_TITLE  \
# 0         01166     TB pneumonia-oth test
# 1         01170    TB pneumothorax-unspec
# 2         01171   TB pneumothorax-no exam
# 3         01172  TB pneumothorx-exam unkn
# 4         01173  TB pneumothorax-micro dx
# ...         ...                       ...
# 14562     V7399     Scrn unspcf viral dis
# 14563      V740     Screening for cholera
# 14564      V741    Screening-pulmonary TB
# 14565      V742     Screening for leprosy
# 14566      V743  Screening for diphtheria
#
#                                               LONG_TITLE
# 0      Tuberculous pneumonia [any form], tubercle bac...
# 1                  Tuberculous pneumothorax, unspecified
# 2      Tuberculous pneumothorax, bacteriological or h...
# 3      Tuberculous pneumothorax, bacteriological or h...
# 4      Tuberculous pneumothorax, tubercle bacilli fou...
# ...                                                  ...
# ...

# %%
df2 = df3.drop(columns=['ROW_ID'])
df2
# Out:
#         SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0              109   172335      1.0     40301
# 1              109   172335      2.0       486
# 2              109   172335      3.0     58281
# 3              109   172335      4.0      5855
# 4              109   172335      5.0      4254
# ...            ...      ...      ...       ...
# 651042       97503   188195      2.0     20280
# 651043       97503   188195      3.0     V5869
# 651044       97503   188195      4.0     V1279
# 651045       97503   188195      5.0      5275
# 651046       97503   188195      6.0      5569
#
# [651047 rows x 4 columns]

# %%
df4 = pandas.merge(df1,df2)
df4 = df4.drop(columns=['SEQ_NUM', 'HADM_ID'])
df4 = df4[df4['LONG_TITLE'].str.contains('Acute kidney failure')]

# %%
TC = pandas.read_csv("ADMISSIONS.csv")
##df = pandas.DataFrame.from_dict(fm_data, orient='index')
df5 = pandas.DataFrame(TC)

# %%
df5
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# ...       ...         ...      ...                  ...                  ...
# 58971   58594       98800   191113  2131-03-30 21:13:00  2131-04-02 15:02:00
# 58972   58595       98802   101071  2151-03-05 20:00:00  2151-03-06 09:10:00
# 58973   58596       98805   122631  2200-09-12 07:15:00  2200-09-20 12:08:00
# 58974   58597       98813   170407  2128-11-11 02:29:00  2128-12-22 13:11:00
# 58975   58598       98813   190264  2131-10-25 03:09:00  2131-10-26 17:44:00
#
# ...

# %%
TC = pandas.read_csv("D_LABITEMS.csv")
##df = pandas.DataFrame.from_dict(fm_data, orient='index')
D_LABITEMS = pandas.DataFrame(TC)

# %%
TC = pandas.read_csv("LABEVENTS.csv")
##df = pandas.DataFrame.from_dict(fm_data, orient='index')
LABEVENTS = pandas.DataFrame(TC)

# %%
LABEVENTS
# Out:
#             ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 0              281           3       NaN   50820  2101-10-12 16:07:00  7.39
# 1              282           3       NaN   50800  2101-10-12 18:17:00   ART
# 2              283           3       NaN   50802  2101-10-12 18:17:00    -1
# 3              284           3       NaN   50804  2101-10-12 18:17:00    22
# 4              285           3       NaN   50808  2101-10-12 18:17:00  0.93
# ...            ...         ...       ...     ...                  ...   ...
# 27854050  27428435       96443  103219.0   50882  2109-12-30 01:40:00    26
# 27854051  27428436       96443  103219.0   50885  2109-12-30 01:40:00   2.1
# 27854052  27428437       96443  103219.0   50902  2109-12-30 01:40:00    97
# 27854053  27428438       96443  103219.0   50911  2109-12-30 01:40:00     2
# 27854054  27428439       96443  103219.0   50912  2109-12-30 01:40:00   1.6
#
#           VALUENUM VALUEUOM      FLAG
# ...

# %%
exp1 = pandas.merge(df5, ICUSTAYS, left_on='SUBJECT_ID', right_on='SUBJECT_ID')

# %%
exp2 = exp1.drop(columns=['HADM_ID_x', 'LOS', 'LAST_WARDID', 'FIRST_WARDID', 'LAST_CAREUNIT', 'FIRST_CAREUNIT', 'DBSOURCE', 'ICUSTAY_ID', 'HADM_ID_y', 'ROW_ID_y', 'DIAGNOSIS', 'ROW_ID_x', 'ROW_ID_x', 'DEATHTIME', 'ADMISSION_TYPE', 'ADMISSION_LOCATION', 'ADMISSION_TYPE', 'ADMISSION_LOCATION', 'DISCHARGE_LOCATION', 'LANGUAGE', 'RELIGION', 'MARITAL_STATUS', 'ETHNICITY', 'HOSPITAL_EXPIRE_FLAG', 'HAS_CHARTEVENTS_DATA'])
exp2 = exp2.dropna()

# %%
LABEVENTS1 = LABEVENTS.sample(100000)

# %%
LABEVENTS1 = LABEVENTS1.drop(columns=['ROW_ID', 'HADM_ID', 'VALUE', 'VALUENUM', 'VALUEUOM', 'FLAG'])

# %%
LABEVENTS1
# Out:
#           SUBJECT_ID  ITEMID            CHARTTIME
# 16518862       27150   51256  2164-12-24 11:37:00
# 9799524        15968   50817  2133-08-05 21:49:00
# 21588495       49053   50862  2149-05-24 03:18:00
# 2736302         4132   51484  2172-04-13 13:45:00
# 8728660        14240   50863  2151-05-30 06:00:00
# ...              ...     ...                  ...
# 21547704       51188   50970  2197-02-10 04:55:00
# 15244573       25332   51222  2148-03-12 09:22:00
# 14930616       24840   50949  2142-01-02 11:20:00
# 4944745         7799   50820  2181-09-12 03:49:00
# 25278909       81236   51268  2136-07-13 07:10:00
#
# [100000 rows x 3 columns]

# %%
exp_o= pandas.merge(LABEVENTS1,D_LABITEMS)
exp_o
# Out:
#        SUBJECT_ID  ITEMID            CHARTTIME  ROW_ID  \
# 0           27150   51256  2164-12-24 11:37:00     456
# 1            9088   51256  2120-08-28 08:00:00     456
# 2           30284   51256  2113-10-27 19:05:00     456
# 3           31275   51256  2199-06-26 12:13:00     456
# 4           61119   51256  2145-04-30 14:31:00     456
# ...           ...     ...                  ...     ...
# 99995       24123   51429  2128-01-27 13:34:00     629
# 99996       14209   50875  2145-12-16 08:05:00      76
# 99997        6214   51517  2131-02-28 11:58:00     717
# 99998       86580   51528  2120-12-17 12:25:00     728
# 99999       56985   51247  2201-11-12 08:30:00     447
#
#                              LABEL             FLUID    CATEGORY LOINC_CODE
# 0                      Neutrophils             Blood  Hematology      761-7
# 1                      Neutrophils             Blood  Hematology      761-7
# ...

# %%
exp3 = exp_o[exp_o['LABEL'].str.contains('Urine')]
exp3
# Out:
#        SUBJECT_ID  ITEMID            CHARTTIME  ROW_ID                LABEL  \
# 60885       27760   51508  2143-10-25 14:25:00     708          Urine Color
# 60886        6960   51508  2126-12-16 16:40:00     708          Urine Color
# 60887       13735   51508  2147-04-14 12:54:00     708          Urine Color
# 60888       22606   51508  2104-08-25 17:45:00     708          Urine Color
# 60889       25475   51508  2124-10-20 16:15:00     708          Urine Color
# ...           ...     ...                  ...     ...                  ...
# 99808       24322   51513  2158-01-03 22:40:00     713  Urine Specimen Type
# 99809        1046   51513  2168-10-29 18:15:00     713  Urine Specimen Type
# 99831       22547   51095  2113-11-29 21:35:00     295     Phosphate, Urine
# 99832        2265   51095  2125-11-28 22:00:00     295     Phosphate, Urine
# 99948       26967   51091  2178-10-31 08:34:00     291     Myoglobin, Urine
#
#        FLUID    CATEGORY LOINC_CODE
# ...

# %%
exp3
# Out:
#        SUBJECT_ID  ITEMID            CHARTTIME  ROW_ID                LABEL  \
# 60885       27760   51508  2143-10-25 14:25:00     708          Urine Color
# 60886        6960   51508  2126-12-16 16:40:00     708          Urine Color
# 60887       13735   51508  2147-04-14 12:54:00     708          Urine Color
# 60888       22606   51508  2104-08-25 17:45:00     708          Urine Color
# 60889       25475   51508  2124-10-20 16:15:00     708          Urine Color
# ...           ...     ...                  ...     ...                  ...
# 99808       24322   51513  2158-01-03 22:40:00     713  Urine Specimen Type
# 99809        1046   51513  2168-10-29 18:15:00     713  Urine Specimen Type
# 99831       22547   51095  2113-11-29 21:35:00     295     Phosphate, Urine
# 99832        2265   51095  2125-11-28 22:00:00     295     Phosphate, Urine
# 99948       26967   51091  2178-10-31 08:34:00     291     Myoglobin, Urine
#
#        FLUID    CATEGORY LOINC_CODE
# ...

# %%
exp4 = pandas.merge(exp2,exp3)
exp4
# Out:
#        SUBJECT_ID            ADMITTIME            DISCHTIME   INSURANCE  \
# 0              78  2177-02-14 00:16:00  2177-02-17 22:12:00    Medicare
# 1             107  2121-11-30 19:24:00  2121-12-05 14:18:00    Medicare
# 2             107  2121-11-30 19:24:00  2121-12-05 14:18:00    Medicare
# 3             107  2121-11-30 19:24:00  2121-12-05 14:18:00    Medicare
# 4             107  2122-05-14 19:37:00  2122-05-18 15:11:00    Medicare
# ...           ...                  ...                  ...         ...
# 16664       93806  2136-11-24 16:21:00  2136-12-05 18:45:00     Private
# 16665       93806  2136-11-24 16:21:00  2136-12-05 18:45:00     Private
# 16666       93806  2136-11-24 16:21:00  2136-12-05 18:45:00     Private
# 16667       93831  2116-11-17 18:05:00  2116-12-01 12:27:00  Government
# 16668       96244  2184-02-01 11:43:00  2184-02-08 13:54:00     Private
#
#                  EDREGTIME            EDOUTTIME               INTIME  \
# ...

# %%
exp4 = exp4.dropna()
df8 = exp4.drop(columns=['ROW_ID', 'DISCHTIME', 'LABEL', 'ITEMID', 'FLUID', 'CATEGORY', 'LOINC_CODE'])

# %%
df8
# Out:
#        SUBJECT_ID            ADMITTIME   INSURANCE            EDREGTIME  \
# 0              78  2177-02-14 00:16:00    Medicare  2177-02-13 21:29:00
# 1             107  2121-11-30 19:24:00    Medicare  2121-11-30 16:40:00
# 2             107  2121-11-30 19:24:00    Medicare  2121-11-30 16:40:00
# 3             107  2121-11-30 19:24:00    Medicare  2121-11-30 16:40:00
# 4             107  2122-05-14 19:37:00    Medicare  2122-05-14 12:29:00
# ...           ...                  ...         ...                  ...
# 16664       93806  2136-11-24 16:21:00     Private  2136-11-24 11:56:00
# 16665       93806  2136-11-24 16:21:00     Private  2136-11-24 11:56:00
# 16666       93806  2136-11-24 16:21:00     Private  2136-11-24 11:56:00
# 16667       93831  2116-11-17 18:05:00  Government  2116-11-17 12:28:00
# 16668       96244  2184-02-01 11:43:00     Private  2184-02-01 08:30:00
#
#                  EDOUTTIME               INTIME              OUTTIME  \
# ...

# %%
df8 = pandas.merge(df8,PATIENTS)
df8 = pandas.merge(df8,df4)

# %%
df8= df8[df8['GENDER'].str.contains('F')]
df8.insert(0, 'CASE_ID', range(1, 1+ len(df8)))

# %%
df8= df8[df8['INSURANCE'].str.contains('Private')]

# %%
df8
# Out:
#        CASE_ID  SUBJECT_ID            ADMITTIME INSURANCE  \
# 2220      1779        3019  2174-08-11 23:10:00   Private
# 2221      1780        3019  2174-08-11 23:10:00   Private
# 2222      1781        3019  2174-08-11 23:10:00   Private
# 2223      1782        3019  2174-08-11 23:10:00   Private
# 2224      1783        3019  2174-08-11 23:10:00   Private
# ...        ...         ...                  ...       ...
# 68132    43201       83180  2187-12-28 16:31:00   Private
# 68221    43253       99319  2139-08-29 05:18:00   Private
# 68225    43254       92393  2148-08-03 12:22:00   Private
# 68226    43255       92393  2148-08-03 12:22:00   Private
# 68229    43258       96244  2184-02-01 11:43:00   Private
#
#                  EDREGTIME            EDOUTTIME               INTIME  \
# 2220   2174-08-11 20:16:00  2174-08-12 06:52:00  2174-05-30 12:33:30
# 2221   2174-08-11 20:16:00  2174-08-12 06:52:00  2174-05-30 12:33:30
# ...

# %%
df9 = df8

# %%
df9
# Out:
#        CASE_ID  SUBJECT_ID            ADMITTIME INSURANCE  \
# 2220      1779        3019  2174-08-11 23:10:00   Private
# 2221      1780        3019  2174-08-11 23:10:00   Private
# 2222      1781        3019  2174-08-11 23:10:00   Private
# 2223      1782        3019  2174-08-11 23:10:00   Private
# 2224      1783        3019  2174-08-11 23:10:00   Private
# ...        ...         ...                  ...       ...
# 68132    43201       83180  2187-12-28 16:31:00   Private
# 68221    43253       99319  2139-08-29 05:18:00   Private
# 68225    43254       92393  2148-08-03 12:22:00   Private
# 68226    43255       92393  2148-08-03 12:22:00   Private
# 68229    43258       96244  2184-02-01 11:43:00   Private
#
#                  EDREGTIME            EDOUTTIME               INTIME  \
# 2220   2174-08-11 20:16:00  2174-08-12 06:52:00  2174-05-30 12:33:30
# 2221   2174-08-11 20:16:00  2174-08-12 06:52:00  2174-05-30 12:33:30
# ...

# %%
df9['Activity1'] ='ADMITTIME/EDREGTIME/EOUTTIME/INTIME_ICU/OUTTIME_ICU/Hematology_TIME' 
df9['Timestamp1'] = df9['ADMITTIME']+'/'+ df9['EDREGTIME']+'/'+df9['EDOUTTIME']+'/'+df9['INTIME']+'/'+df9['OUTTIME']+'/'+df9['CHARTTIME']
df9
# Out:
#        CASE_ID  SUBJECT_ID            ADMITTIME INSURANCE  \
# 2220      1779        3019  2174-08-11 23:10:00   Private
# 2221      1780        3019  2174-08-11 23:10:00   Private
# 2222      1781        3019  2174-08-11 23:10:00   Private
# 2223      1782        3019  2174-08-11 23:10:00   Private
# 2224      1783        3019  2174-08-11 23:10:00   Private
# ...        ...         ...                  ...       ...
# 68132    43201       83180  2187-12-28 16:31:00   Private
# 68221    43253       99319  2139-08-29 05:18:00   Private
# 68225    43254       92393  2148-08-03 12:22:00   Private
# 68226    43255       92393  2148-08-03 12:22:00   Private
# 68229    43258       96244  2184-02-01 11:43:00   Private
#
#                  EDREGTIME            EDOUTTIME               INTIME  \
# 2220   2174-08-11 20:16:00  2174-08-12 06:52:00  2174-05-30 12:33:30
# 2221   2174-08-11 20:16:00  2174-08-12 06:52:00  2174-05-30 12:33:30
# ...

# %%
df9
# Out:
#        CASE_ID  SUBJECT_ID            ADMITTIME INSURANCE  \
# 2220      1779        3019  2174-08-11 23:10:00   Private
# 2221      1780        3019  2174-08-11 23:10:00   Private
# 2222      1781        3019  2174-08-11 23:10:00   Private
# 2223      1782        3019  2174-08-11 23:10:00   Private
# 2224      1783        3019  2174-08-11 23:10:00   Private
# ...        ...         ...                  ...       ...
# 68132    43201       83180  2187-12-28 16:31:00   Private
# 68221    43253       99319  2139-08-29 05:18:00   Private
# 68225    43254       92393  2148-08-03 12:22:00   Private
# 68226    43255       92393  2148-08-03 12:22:00   Private
# 68229    43258       96244  2184-02-01 11:43:00   Private
#
#                  EDREGTIME            EDOUTTIME               INTIME  \
# 2220   2174-08-11 20:16:00  2174-08-12 06:52:00  2174-05-30 12:33:30
# 2221   2174-08-11 20:16:00  2174-08-12 06:52:00  2174-05-30 12:33:30
# ...

# %%
df9["Activity"] = df9["Activity1"].str.split("/")
#df9["T"] = df9["Timestamp"].str.split("/")
df10 = df9.explode("Activity").drop(columns=['ADMITTIME', 'EDREGTIME', 'EDOUTTIME','CHARTTIME', 'INTIME', 'OUTTIME', 'Activity1', 'Timestamp1'])
df10.insert(0, 'ID', range(1, 1+ len(df10)))
df10
# Out:
#          ID  CASE_ID  SUBJECT_ID INSURANCE  ROW_ID GENDER  \
# 2220      1     1779        3019   Private    2858      F
# 2220      2     1779        3019   Private    2858      F
# 2220      3     1779        3019   Private    2858      F
# 2220      4     1779        3019   Private    2858      F
# 2220      5     1779        3019   Private    2858      F
# ...     ...      ...         ...       ...     ...    ...
# 68229  6968    43258       96244   Private   45532      F
# 68229  6969    43258       96244   Private   45532      F
# 68229  6970    43258       96244   Private   45532      F
# 68229  6971    43258       96244   Private   45532      F
# 68229  6972    43258       96244   Private   45532      F
#
#                        DOB                  DOD             DOD_HOSP  \
# 2220   2148-01-31 00:00:00  2174-08-16 00:00:00  2174-08-16 00:00:00
# 2220   2148-01-31 00:00:00  2174-08-16 00:00:00  2174-08-16 00:00:00
# ...

# %%
df10.head(20)
# Out:
#       ID  CASE_ID  SUBJECT_ID INSURANCE  ROW_ID GENDER                  DOB  \
# 2220   1     1779        3019   Private    2858      F  2148-01-31 00:00:00
# 2220   2     1779        3019   Private    2858      F  2148-01-31 00:00:00
# 2220   3     1779        3019   Private    2858      F  2148-01-31 00:00:00
# 2220   4     1779        3019   Private    2858      F  2148-01-31 00:00:00
# 2220   5     1779        3019   Private    2858      F  2148-01-31 00:00:00
# 2220   6     1779        3019   Private    2858      F  2148-01-31 00:00:00
# 2221   7     1780        3019   Private    2858      F  2148-01-31 00:00:00
# 2221   8     1780        3019   Private    2858      F  2148-01-31 00:00:00
# 2221   9     1780        3019   Private    2858      F  2148-01-31 00:00:00
# 2221  10     1780        3019   Private    2858      F  2148-01-31 00:00:00
# 2221  11     1780        3019   Private    2858      F  2148-01-31 00:00:00
# ...

# %%
df9["Timestamp"] = df9["Timestamp1"].str.split("/")
df11 = df9.explode("Timestamp").drop(columns=['SUBJECT_ID', 'ADMITTIME','EDREGTIME', 'EDOUTTIME','CHARTTIME', 'INTIME', 'OUTTIME', 'Activity1', 'Activity', 'Timestamp1'])
df11.insert(0, 'ID', range(1, 1+ len(df11)))
df11
# Out:
#          ID  CASE_ID INSURANCE  ROW_ID GENDER                  DOB  \
# 2220      1     1779   Private    2858      F  2148-01-31 00:00:00
# 2220      2     1779   Private    2858      F  2148-01-31 00:00:00
# 2220      3     1779   Private    2858      F  2148-01-31 00:00:00
# 2220      4     1779   Private    2858      F  2148-01-31 00:00:00
# 2220      5     1779   Private    2858      F  2148-01-31 00:00:00
# ...     ...      ...       ...     ...    ...                  ...
# 68229  6968    43258   Private   45532      F  2112-09-12 00:00:00
# 68229  6969    43258   Private   45532      F  2112-09-12 00:00:00
# 68229  6970    43258   Private   45532      F  2112-09-12 00:00:00
# 68229  6971    43258   Private   45532      F  2112-09-12 00:00:00
# 68229  6972    43258   Private   45532      F  2112-09-12 00:00:00
#
#                        DOD             DOD_HOSP              DOD_SSN  \
# 2220   2174-08-16 00:00:00  2174-08-16 00:00:00  2174-08-16 00:00:00
# ...

# %%
df11.head(20)
# Out:
#       ID  CASE_ID INSURANCE  ROW_ID GENDER                  DOB  \
# 2220   1     1779   Private    2858      F  2148-01-31 00:00:00
# 2220   2     1779   Private    2858      F  2148-01-31 00:00:00
# 2220   3     1779   Private    2858      F  2148-01-31 00:00:00
# 2220   4     1779   Private    2858      F  2148-01-31 00:00:00
# 2220   5     1779   Private    2858      F  2148-01-31 00:00:00
# 2220   6     1779   Private    2858      F  2148-01-31 00:00:00
# 2221   7     1780   Private    2858      F  2148-01-31 00:00:00
# 2221   8     1780   Private    2858      F  2148-01-31 00:00:00
# 2221   9     1780   Private    2858      F  2148-01-31 00:00:00
# 2221  10     1780   Private    2858      F  2148-01-31 00:00:00
# 2221  11     1780   Private    2858      F  2148-01-31 00:00:00
# 2221  12     1780   Private    2858      F  2148-01-31 00:00:00
# 2222  13     1781   Private    2858      F  2148-01-31 00:00:00
# 2222  14     1781   Private    2858      F  2148-01-31 00:00:00
# ...

# %%
import pandas as pd


event_log = pd.merge(df10, df11, left_on='ID', right_on='ID') # 文件合并，left_on=左侧DataFrame中的列；right_on=右侧DataFrame中的列
event_log = event_log.drop(columns=['CASE_ID_y', 'ID'])
#event_log.to_csv("event_log1.csv")

# %%
event_log.head(20)
# Out:
#     CASE_ID_x  SUBJECT_ID INSURANCE_x  ROW_ID_x GENDER_x                DOB_x  \
# 0        1779        3019     Private      2858        F  2148-01-31 00:00:00
# 1        1779        3019     Private      2858        F  2148-01-31 00:00:00
# 2        1779        3019     Private      2858        F  2148-01-31 00:00:00
# 3        1779        3019     Private      2858        F  2148-01-31 00:00:00
# 4        1779        3019     Private      2858        F  2148-01-31 00:00:00
# 5        1779        3019     Private      2858        F  2148-01-31 00:00:00
# 6        1780        3019     Private      2858        F  2148-01-31 00:00:00
# 7        1780        3019     Private      2858        F  2148-01-31 00:00:00
# 8        1780        3019     Private      2858        F  2148-01-31 00:00:00
# 9        1780        3019     Private      2858        F  2148-01-31 00:00:00
# 10       1780        3019     Private      2858        F  2148-01-31 00:00:00
# ...

# %%
#event_log['Timestamp_y'].dt.strftime('%Y-%m-%d %H:%M')

#event_log['Timestamp_y']
event_log['Timestamp'] = event_log['Timestamp'].map(lambda x: str(x)[:-3])

# %%
event_log
# Out:
#       CASE_ID_x  SUBJECT_ID INSURANCE_x  ROW_ID_x GENDER_x  \
# 0          1779        3019     Private      2858        F
# 1          1779        3019     Private      2858        F
# 2          1779        3019     Private      2858        F
# 3          1779        3019     Private      2858        F
# 4          1779        3019     Private      2858        F
# ...         ...         ...         ...       ...      ...
# 6967      43258       96244     Private     45532        F
# 6968      43258       96244     Private     45532        F
# 6969      43258       96244     Private     45532        F
# 6970      43258       96244     Private     45532        F
# 6971      43258       96244     Private     45532        F
#
#                     DOB_x                DOD_x           DOD_HOSP_x  \
# 0     2148-01-31 00:00:00  2174-08-16 00:00:00  2174-08-16 00:00:00
# 1     2148-01-31 00:00:00  2174-08-16 00:00:00  2174-08-16 00:00:00
# ...

# %%
event_log.to_csv("Female_Pri.csv")
